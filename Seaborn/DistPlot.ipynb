# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use("fivethirtyeight")

# %%
data = sns.load_dataset("titanic")

# %%
data.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 278         0       3    male   7.0      4      1  29.125        Q  Third
# 35          0       1    male  42.0      1      0  52.000        S  First
# 468         0       3    male   NaN      0      0   7.725        Q  Third
# 885         0       3  female  39.0      0      5  29.125        Q  Third
# 559         1       3  female  36.0      1      0  17.400        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 278  child       False  NaN   Queenstown    no  False
# 35     man        True  NaN  Southampton    no  False
# 468    man        True  NaN   Queenstown    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 559  woman       False  NaN  Southampton   yes  False

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data["age"].fillna(data["age"].mean() , inplace=True)
# Out:
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\93914742.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["age"].fillna(data["age"].mean() , inplace=True)

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.distplot(data["age"])
# Out:
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\2784439929.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["age"])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(data["age"] ,bins = 10 ,  kde = False)
# Out:
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\191627428.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["age"] ,bins = 10 ,  kde = False)
# <Axes: xlabel='age'>

# %%
sns.distplot(data["age"] , hist = False)
# Out:
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\985497265.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["age"] , hist = False)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(data["age"] , hist = False , kde = False , rug = True)
# Out:
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\4171171609.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["age"] , hist = False , kde = False , rug = True)
# <Axes: xlabel='age'>

# %%
sns.distplot(data[data["survived"] ==1]["age"] )
sns.distplot(data[data["survived"] ==0]["age"] )
# Out:
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\756366616.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data["survived"] ==1]["age"] )
# C:\Users\umark\AppData\Local\Temp\ipykernel_16280\756366616.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data["survived"] ==0]["age"] )
# <Axes: xlabel='age', ylabel='Density'>
